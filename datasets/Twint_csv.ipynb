# %%
import twint
import nest_asyncio
nest_asyncio.apply()
c = twint.Config()
c.Search = "covid-19 OR education"
#c.Links = "exclude"
c.Lang = "en"
c.Pandas = True
#c.Show_hashtags = False
c.Hide_output = True
c.Store_csv = True
#c.Since = "2020-11-11 00:00:00"
#c.Until = "2021-12-12 00:00:00"
c.Output = "C:/Users/Nasibullah Qarizada/Desktop/3.csv"
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\NASIBU~1\AppData\Local\Temp/ipykernel_70516/3458436802.py in <module>
#      13 #c.Until = "2021-12-12 00:00:00"
#      14 c.Output = "C:/Users/Nasibullah Qarizada/Desktop/3.csv"
# ---> 15 twint.run.Search(c)
#
# C:\anaconda3\lib\site-packages\twint\run.py in Search(config, callback)
#     408     config.Followers = False
#     409     config.Profile = False
# --> 410     run(config, callback)
#     411     if config.Pandas_au:
#     412         storage.panda._autoget("tweet")
#
# C:\anaconda3\lib\site-packages\twint\run.py in run(config, callback)
#     327         raise
#     328
# --> 329     get_event_loop().run_until_complete(Twint(config).main(callback))
#     330
#     331
#
# C:\anaconda3\lib\site-packages\nest_asyncio.py in run_until_complete(self, future)
#      62                 f._log_destroy_pending = False
# ...
